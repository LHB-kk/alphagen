# %%
import numpy as np
from qlib.data import D
cal: np.ndarray = D.calendar()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 3
#       1 import numpy as np
#       2 from qlib.data import D
# ----> 3 cal: np.ndarray = D.calendar()
#
# File c:\Users\15416\miniconda3\envs\alphagen\lib\site-packages\qlib\utils\__init__.py:872, in Wrapper.__getattr__(self, key)
#     870 def __getattr__(self, key):
#     871     if self.__dict__.get("_provider", None) is None:
# --> 872         raise AttributeError("Please run qlib.init() first using qlib")
#     873     return getattr(self._provider, key)
#
# AttributeError: Please run qlib.init() first using qlib

# %%
import qlib
from qlib.constant import REG_CN
from qlib.data import D


if __name__ == "__main__":
    qlib.init(provider_uri='qlib_data/cn_data', region=REG_CN)
# Out:
# [935420:MainThread](2025-06-02 14:48:35,281) INFO - qlib.Initialization - [config.py:420] - default_conf: client.
# [935420:MainThread](2025-06-02 14:48:35,285) INFO - qlib.Initialization - [__init__.py:74] - qlib successfully initialized based on client settings.
# [935420:MainThread](2025-06-02 14:48:35,286) INFO - qlib.Initialization - [__init__.py:76] - data_path={'__DEFAULT_FREQ': WindowsPath('D:/Code/alphagen/qlib_data/cn_data')}

# %%
D.calendar(start_time='2010-01-01', end_time='2017-12-31', freq='day')[:2]
# Out:
# array([Timestamp('2010-01-04 00:00:00'), Timestamp('2010-01-05 00:00:00')],
#       dtype=object)

# %%
D.calendar(start_time='2010-01-01', end_time='2017-12-31', freq='day')
# Out:
# array([Timestamp('2010-01-04 00:00:00'), Timestamp('2010-01-05 00:00:00'),
#        Timestamp('2010-01-06 00:00:00'), ...,
#        Timestamp('2017-12-27 00:00:00'), Timestamp('2017-12-28 00:00:00'),
#        Timestamp('2017-12-29 00:00:00')], shape=(1944,), dtype=object)

# %%
cal: np.ndarray = D.calendar()
